# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# !sudo mkdir /content/drive1
# !google-drive-ocamlfuse /content/drive1
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144617 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# ...

# %%
# !unzip '/content/drive1/3DProject.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/7375.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/14146.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/8779.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/16130.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/20777.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/13100.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/15749.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/9307.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/000805.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/7480.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/13919.txt
#   inflating: 3DOD_thesis/eval_kitti/build/data/object/label_2/22460.txt
# ...

# %%
# !cp '/content/drive/My Drive/Copie de best_weights_kitti.pth' '/content'
# !mv '/content/Copie de best_weights_kitti.pth' '/content/KITTI-2d-object-detection'

# %%
# !unzip '/content/drive1/Copie de data_lidar.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/Voxelnet/crop_data/validation/velodyne/004238.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/004236.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/006419.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/007418.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/004264.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/003237.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/006671.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/003431.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/003340.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/006915.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/000586.bin
#   inflating: content/Voxelnet/crop_data/validation/velodyne/000449.bin
# ...

# %%
#import os
#os.rename('/content/content/Voxelnet/crop_data/validation', '/content/content/Voxelnet/crop_data/testing')
#choose the image you want from training or testing set:
import shutil
img='000007.png'
source='/content/content/Voxelnet/crop_data/testing/image_2/'+img
destination ='/content/KITTI-2d-object-detection/images/'
shutil.copy(source, destination)
# Out:
# '/content/KITTI-2d-object-detection/images/000007.png'

# %%
# !python /content/KITTI-2d-object-detection/src/detect.py
# Out:
# Cuda available for inference
# data size : 2
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.429019
# 	+ Batch 1, Inference Time: 0:00:00.195462
#
# Saving images:
# (0) Image: '/content/KITTI-2d-object-detection/images/000000.png'
# torch.Size([1, 7])
# 	+ Label: Pedestrian, Conf: 1.00000
# (1) Image: '/content/KITTI-2d-object-detection/images/000003.png'
# torch.Size([1, 7])
# 	+ Label: Car, Conf: 0.99980
# (2) Image: '/content/KITTI-2d-object-detection/images/000007.png'
# torch.Size([4, 7])
# 	+ Label: Car, Conf: 1.00000
# 	+ Label: Car, Conf: 0.99984
# 	+ Label: Car, Conf: 1.00000
# 	+ Label: Cyclist, Conf: 0.99854

# %%
import os, shutil
liste=['/content/3DOD_thesis/data/kitti/object/testing/calib','/content/3DOD_thesis/data/kitti/object/testing/image_2','/content/3DOD_thesis/data/kitti/object/testing/velodyne']
for folder in liste:
  for filename in os.listdir(folder):
      file_path = os.path.join(folder, filename)
      try:
          if os.path.isfile(file_path) or os.path.islink(file_path):
              os.unlink(file_path)
          elif os.path.isdir(file_path):
              shutil.rmtree(file_path)
      except Exception as e:
          print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
#copy files in folders
shutil.copy('/content/content/Voxelnet/crop_data/testing/calib/'+img[:6]+'.txt','/content/3DOD_thesis/data/kitti/object/testing/calib')
shutil.copy('/content/content/Voxelnet/crop_data/testing/image_2/'+img,'/content/3DOD_thesis/data/kitti/object/testing/image_2')
shutil.copy('/content/content/Voxelnet/crop_data/testing/velodyne/'+img[:6]+'.bin','/content/3DOD_thesis/data/kitti/object/testing/velodyne')
# Out:
# '/content/3DOD_thesis/data/kitti/object/testing/velodyne/000007.bin'

# %%
shutil.rmtree('/content/3DOD_thesis/data/kitti/meta/object/testing')
# !cp -r '/content/KITTI-2d-object-detection/testing/' '/content/3DOD_thesis/data/kitti/meta/object'

# %%
# !python  /content/3DOD_thesis/Image-Only/eval_imgnet_test.py
#eval_frustum_pointnet_img_test.py
# Out:
# step: 1/0

# %%
# !pip3 install open3d-python
# Out:
# ...
#      |████████████████████████████████| 3.7MB 4.7MB/s
# ...

# %%
# !python /content/3DOD_thesis/visualization/visualize_eval_test.py
# Out:
# 000007
